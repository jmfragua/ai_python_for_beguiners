# %%
import shutil
import os

os.getcwd()
# Out:
# '/home/jovyan/work'

# %%
import shutil
import os

# Nombre del archivo que se va a crear
output_filename = 'ai_python_for_beguiners'
# Formato de compresión (puedes usar 'zip' o 'tar')
format = 'zip'

# Comprimir todo el directorio actual
shutil.make_archive(output_filename, format, os.getcwd())

print(f"¡Listo! Se ha creado el archivo: {output_filename}.{format}")
